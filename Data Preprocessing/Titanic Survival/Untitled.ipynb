# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Sarthak Aggarwal\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Sarthak Aggarwal\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv("titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# #### if following code does not work run these 2 codes:
# - pip install --upgrade pandas dask sktime
# - pip install pycaret[full] pandas dask sktime

# %%
from pycaret.classification import *
s = setup(data=df, target='Survived')
# Out:
# <style type="text/css">
# #T_020da_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_020da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_020da_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_020da_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_020da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_020da_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_020da_row0_col1" class="data row0 col1" >1319</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_020da_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_020da_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_020da_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_020da_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_020da_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_020da_row3_col1" class="data row3 col1" >(891, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_020da_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_020da_row4_col1" class="data row4 col1" >(891, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_020da_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_020da_row5_col1" class="data row5 col1" >(623, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_020da_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_020da_row6_col1" class="data row6 col1" >(268, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_020da_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_020da_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_020da_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_020da_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_020da_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_020da_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_020da_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_020da_row10_col1" class="data row10 col1" >79.5%</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_020da_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_020da_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_020da_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_020da_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_020da_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_020da_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_020da_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_020da_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_020da_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_020da_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_020da_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_020da_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_020da_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_020da_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_020da_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_020da_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_020da_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_020da_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_020da_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_020da_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_020da_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_020da_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_020da_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_020da_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_020da_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_020da_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_020da_row23_col1" class="data row23 col1" >d606</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm=compare_models()
# Out:
# <style type="text/css">
# #T_d1bd2 th {
#   text-align: left;
# }
# #T_d1bd2_row0_col0, #T_d1bd2_row0_col2, #T_d1bd2_row0_col3, #T_d1bd2_row0_col4, #T_d1bd2_row0_col5, #T_d1bd2_row0_col6, #T_d1bd2_row0_col7, #T_d1bd2_row1_col0, #T_d1bd2_row1_col2, #T_d1bd2_row1_col3, #T_d1bd2_row1_col4, #T_d1bd2_row1_col5, #T_d1bd2_row1_col6, #T_d1bd2_row1_col7, #T_d1bd2_row2_col0, #T_d1bd2_row2_col2, #T_d1bd2_row2_col3, #T_d1bd2_row2_col4, #T_d1bd2_row2_col5, #T_d1bd2_row2_col6, #T_d1bd2_row2_col7, #T_d1bd2_row3_col0, #T_d1bd2_row3_col2, #T_d1bd2_row3_col3, #T_d1bd2_row3_col4, #T_d1bd2_row3_col5, #T_d1bd2_row3_col6, #T_d1bd2_row3_col7, #T_d1bd2_row4_col0, #T_d1bd2_row4_col2, #T_d1bd2_row4_col3, #T_d1bd2_row4_col4, #T_d1bd2_row4_col5, #T_d1bd2_row4_col6, #T_d1bd2_row4_col7, #T_d1bd2_row5_col0, #T_d1bd2_row5_col2, #T_d1bd2_row5_col3, #T_d1bd2_row5_col4, #T_d1bd2_row5_col5, #T_d1bd2_row5_col6, #T_d1bd2_row5_col7, #T_d1bd2_row6_col0, #T_d1bd2_row6_col2, #T_d1bd2_row6_col3, #T_d1bd2_row6_col4, #T_d1bd2_row6_col5, #T_d1bd2_row6_col6, #T_d1bd2_row6_col7, #T_d1bd2_row7_col0, #T_d1bd2_row7_col2, #T_d1bd2_row7_col3, #T_d1bd2_row7_col4, #T_d1bd2_row7_col5, #T_d1bd2_row7_col6, #T_d1bd2_row7_col7, #T_d1bd2_row8_col0, #T_d1bd2_row8_col3, #T_d1bd2_row8_col4, #T_d1bd2_row8_col5, #T_d1bd2_row8_col6, #T_d1bd2_row8_col7, #T_d1bd2_row9_col0, #T_d1bd2_row9_col2, #T_d1bd2_row9_col3, #T_d1bd2_row9_col4, #T_d1bd2_row9_col5, #T_d1bd2_row9_col6, #T_d1bd2_row9_col7, #T_d1bd2_row10_col0, #T_d1bd2_row10_col2, #T_d1bd2_row10_col3, #T_d1bd2_row10_col4, #T_d1bd2_row10_col5, #T_d1bd2_row10_col6, #T_d1bd2_row10_col7, #T_d1bd2_row11_col0, #T_d1bd2_row11_col1, #T_d1bd2_row11_col2, #T_d1bd2_row11_col3, #T_d1bd2_row11_col4, #T_d1bd2_row11_col5, #T_d1bd2_row11_col6, #T_d1bd2_row11_col7, #T_d1bd2_row12_col0, #T_d1bd2_row12_col1, #T_d1bd2_row12_col2, #T_d1bd2_row12_col3, #T_d1bd2_row12_col4, #T_d1bd2_row12_col5, #T_d1bd2_row12_col6, #T_d1bd2_row12_col7, #T_d1bd2_row13_col0, #T_d1bd2_row13_col1, #T_d1bd2_row13_col2, #T_d1bd2_row13_col3, #T_d1bd2_row14_col0, #T_d1bd2_row14_col1, #T_d1bd2_row14_col2, #T_d1bd2_row14_col3, #T_d1bd2_row14_col4, #T_d1bd2_row14_col5, #T_d1bd2_row14_col6, #T_d1bd2_row14_col7, #T_d1bd2_row15_col0, #T_d1bd2_row15_col1, #T_d1bd2_row15_col2, #T_d1bd2_row15_col4, #T_d1bd2_row15_col5, #T_d1bd2_row15_col6, #T_d1bd2_row15_col7 {
#   text-align: left;
# }
# #T_d1bd2_row0_col1, #T_d1bd2_row1_col1, #T_d1bd2_row2_col1, #T_d1bd2_row3_col1, #T_d1bd2_row4_col1, #T_d1bd2_row5_col1, #T_d1bd2_row6_col1, #T_d1bd2_row7_col1, #T_d1bd2_row8_col1, #T_d1bd2_row8_col2, #T_d1bd2_row9_col1, #T_d1bd2_row10_col1, #T_d1bd2_row13_col4, #T_d1bd2_row13_col5, #T_d1bd2_row13_col6, #T_d1bd2_row13_col7, #T_d1bd2_row15_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d1bd2_row0_col8, #T_d1bd2_row1_col8, #T_d1bd2_row2_col8, #T_d1bd2_row3_col8, #T_d1bd2_row4_col8, #T_d1bd2_row5_col8, #T_d1bd2_row6_col8, #T_d1bd2_row7_col8, #T_d1bd2_row8_col8, #T_d1bd2_row9_col8, #T_d1bd2_row10_col8, #T_d1bd2_row11_col8, #T_d1bd2_row12_col8, #T_d1bd2_row13_col8, #T_d1bd2_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d1bd2_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d1bd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1bd2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1bd2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d1bd2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d1bd2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d1bd2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d1bd2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d1bd2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d1bd2_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d1bd2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1bd2_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_d1bd2_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_d1bd2_row0_col1" class="data row0 col1" >0.6164</td>
#       <td id="T_d1bd2_row0_col2" class="data row0 col2" >0.4955</td>
#       <td id="T_d1bd2_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_d1bd2_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_d1bd2_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_d1bd2_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_d1bd2_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_d1bd2_row0_col8" class="data row0 col8" >0.1370</td>
#     </tr>
#     <tr>
#       <th id="T_d1bd2_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_d1bd2_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_d1bd2_row1_col1" class="data row1 col1" >0.6164</td>
#       <td id="T_d1bd2_row1_col2" class="data row1 col2" >0.5000</td>
#       <td id="T_d1bd2_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_d1bd2_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_d1bd2_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_d1bd2_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_d1bd2_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_d1bd2_row1_col8" class="data row1 col8" >0.1380</td>
#     </tr>
#     <tr>
#       <th id="T_d1bd2_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_d1bd2_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_d1bd2_row2_col1" class="data row2 col1" >0.6164</td>
#       <td id="T_d1bd2_row2_col2" class="data row2 col2" >0.5190</td>
#       <td id="T_d1bd2_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_d1bd2_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_d1bd2_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_d1bd2_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_d1bd2_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_d1bd2_row2_col8" class="data row2 col8" >0.2940</td>
#     </tr>
#     <tr>
#       <th id="T_d1bd2_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_d1bd2_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_d1bd2_row3_col1" class="data row3 col1" >0.6164</td>
#       <td id="T_d1bd2_row3_col2" class="data row3 col2" >0.5000</td>
#       <td id="T_d1bd2_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_d1bd2_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_d1bd2_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_d1bd2_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_d1bd2_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_d1bd2_row3_col8" class="data row3 col8" >0.1430</td>
#     </tr>
#     <tr>
#       <th id="T_d1bd2_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_d1bd2_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_d1bd2_row4_col1" class="data row4 col1" >0.6164</td>
#       <td id="T_d1bd2_row4_col2" class="data row4 col2" >0.5000</td>
#       <td id="T_d1bd2_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_d1bd2_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_d1bd2_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_d1bd2_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_d1bd2_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_d1bd2_row4_col8" class="data row4 col8" >0.1430</td>
#     </tr>
#     <tr>
#       <th id="T_d1bd2_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_d1bd2_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_d1bd2_row5_col1" class="data row5 col1" >0.6164</td>
#       <td id="T_d1bd2_row5_col2" class="data row5 col
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]
