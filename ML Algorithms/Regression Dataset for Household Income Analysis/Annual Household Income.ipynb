# %% [markdown]
# # 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Reading Dataset

# %%
df=pd.read_csv("data.csv")
df
# Out:
#       Age Education_Level  Occupation  Number_of_Dependents  Location  \
# 0      56        Master's  Technology                     5     Urban
# 1      69     High School     Finance                     0     Urban
# 2      46      Bachelor's  Technology                     1     Urban
# 3      32     High School      Others                     2     Urban
# 4      60      Bachelor's     Finance                     3     Urban
# ...   ...             ...         ...                   ...       ...
# 9995   58     High School      Others                     0  Suburban
# 9996   23        Master's  Technology                     3     Urban
# 9997   41       Doctorate   Education                     3     Urban
# 9998   44     High School   Education                     0     Urban
# 9999   37     High School  Healthcare                     0  Suburban
#
#       Work_Experience Marital_Status Employment_Status  Household_Size  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['Age', 'Education_Level', 'Occupation', 'Number_of_Dependents',
#        'Location', 'Work_Experience', 'Marital_Status', 'Employment_Status',
#        'Household_Size', 'Homeownership_Status', 'Type_of_Housing', 'Gender',
#        'Primary_Mode_of_Transportation', 'Income'],
#       dtype='object')

# %% [markdown]
# ## Dataset Description
#
# This dataset contains demographic and socio-economic information about households. The features included are:
#
# - **Age**: Age of the primary household member (range: 18 to 70 years).
# - **Education Level**: Highest education level attained by the primary household member. Categories include:
#   - High School
#   - Bachelor's
#   - Master's
#   - Doctorate
# - **Occupation**: Type of occupation of the primary household member. Categories include:
#   - Healthcare
#   - Education
#   - Technology
#   - Finance
#   - Others
# - **Number of Dependents**: Number of dependents in the household (range: 0 to 5).
# - **Location**: Residential location of the household. Categories include:
#   - Urban
#   - Suburban
#   - Rural
# - **Work Experience**: Years of work experience of the primary household member (range: 0 to 50 years).
# - **Marital Status**: Marital status of the primary household member. Categories include:
#   - Single
#   - Married
#   - Divorced
# - **Employment Status**: Employment status of the primary household member. Categories include:
#   - Full-time
#   - Part-time
#   - Self-employed
# - **Household Size**: Total number of individuals living in the household (range: 1 to 7).
# - **Homeownership Status**: Homeownership status of the household. Categories include:
#   - Own
#   - Rent
# - **Type of Housing**: Type of housing the household resides in. Categories include:
#   - Apartment
#   - Single-family home
#   - Townhouse
# - **Gender**: Gender of the primary household member. Categories include:
#   - Male
#   - Female
# - **Primary Mode of Transportation**: Primary mode of transportation used by the household member. Categories include:
#   - Car
#   - Public transit
#   - Biking
#   - Walking
# - **Annual Household Income**: Actual annual household income, derived from a combination of features with added noise. Unit: USD
#
# with added noise. Unit USD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             10000 non-null  int64
#  1   Education_Level                 10000 non-null  object
#  2   Occupation                      10000 non-null  object
#  3   Number_of_Dependents            10000 non-null  int64
#  4   Location                        10000 non-null  object
#  5   Work_Experience                 10000 non-null  int64
#  6   Marital_Status                  10000 non-null  object
#  7   Employment_Status               10000 non-null  object
#  8   Household_Size                  10000 non-null  int64
#  9   Homeownership_Status            10000 non-null  object
#  10  Type_of_Housing                 10000 non-null  object
#  11  Gender                          10000 non-null  object
# ...

# %% [markdown]
# #### There are 5 numerical columns and 9 categorical columns

# %%
df.isnull().sum()
# Out:
# Age                               0
# Education_Level                   0
# Occupation                        0
# Number_of_Dependents              0
# Location                          0
# Work_Experience                   0
# Marital_Status                    0
# Employment_Status                 0
# Household_Size                    0
# Homeownership_Status              0
# Type_of_Housing                   0
# Gender                            0
# Primary_Mode_of_Transportation    0
# Income                            0
# dtype: int64

# %% [markdown]
# #### There is no Null Value in dataset

# %%
df.nunique()
# Out:
# Age                                 53
# Education_Level                      4
# Occupation                           5
# Number_of_Dependents                 6
# Location                             3
# Work_Experience                     51
# Marital_Status                       3
# Employment_Status                    3
# Household_Size                       7
# Homeownership_Status                 2
# Type_of_Housing                      3
# Gender                               2
# Primary_Mode_of_Transportation       4
# Income                            7667
# dtype: int64

# %%
df.describe()
# Out:
#                 Age  Number_of_Dependents  Work_Experience  Household_Size  \
# count  10000.000000          10000.000000     10000.000000    10000.000000
# mean      44.021700              2.527000        24.858800        3.989600
# std       15.203998              1.713991        14.652622        2.010496
# min       18.000000              0.000000         0.000000        1.000000
# 25%       31.000000              1.000000        12.000000        2.000000
# 50%       44.000000              3.000000        25.000000        4.000000
# 75%       57.000000              4.000000        37.000000        6.000000
# max       70.000000              5.000000        50.000000        7.000000
#
#              Income
# count  1.000000e+04
# mean   8.168382e+05
# std    1.821089e+06
# min    3.104400e+04
# 25%    6.844600e+04
# 50%    7.294300e+04
# 75%    3.506675e+05
# max    9.992571e+06

# %% [markdown]
# # 3. Numerical and categorical columns

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols=df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables are ",cat_cols)
print("Numerical Variables are ",num_cols)
# Out:
# Categorical Variables are  Index(['Education_Level', 'Occupation', 'Location', 'Marital_Status',
#        'Employment_Status', 'Homeownership_Status', 'Type_of_Housing',
#        'Gender', 'Primary_Mode_of_Transportation'],
#       dtype='object')
# Numerical Variables are  ['Age', 'Number_of_Dependents', 'Work_Experience', 'Household_Size', 'Income']

# %% [markdown]
# # 4. Exploratory Data Analysis (EDA)
#
# ### Key Features of EDA
#
# #### 1. Understanding the Data
# - EDA helps in understanding the structure, distribution, and characteristics of the dataset.
# - Provides insight into the nature of the data, such as its range, variability, and central tendencies.
# - Common techniques:
#   - Descriptive statistics (mean, median, mode, standard deviation, etc.)
#   - Data distribution visualizations (histograms, box plots, etc.)
#
# #### 2. Identifying Patterns and Relationships
# - EDA techniques allow for the identification of patterns, trends, and relationships within the data.
# - Discover correlations between variables, detect outliers, and uncover hidden patterns.
# - Common techniques:
#   - Scatter plots, correlation matrices, heatmaps, pair plots
#
# #### 3. Feature Selection
# - EDA helps in identifying important features or variables that are relevant for modeling or analysis.
# - Examining the relationships between variables and their associations with the target variable.
# - Common techniques:
#   - Feature correlation analysis, importance ranking, variance analysis
#
# #### 4. Data Cleaning and Preprocessing
# - EDA helps in detecting and addressing data quality issues such as missing values, outliers, and inconsistencies.
# - Identifying problematic data points early in the analysis process to take appropriate steps to clean and preprocess the data.
# - Common techniques:
#   - Missing value analysis, outlier detection, data transformation

# %% [markdown]
# ## 4.1. Univariate Analysis:
# - Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# - Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.

# %%
# Histogram and Boxplot
for col in num_cols:
    print(col)
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)
    sns.histplot(df[col],kde=True)
    plt.ylabel("Count")
    plt.subplot(1,2,2)
    sns.boxplot(df[col])
    plt.show()
# Out:
# Age
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Number_of_Dependents
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Work_Experience
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Household_Size
# ...

# %% [markdown]
# ##### Age, Number of dependents, Work Experience, Household is almost uniformly distributed in dataset
# ##### Mostly Income lies in 5-6 digits but there are some outliers present in Income columnn also which are extremely high

# %%
# Countplot for categorical columns
for col in cat_cols:
    print(col)
    plt.bar(df[col].value_counts().index, df[col].value_counts().values)
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
# Out:
# Education_Level
# Occupation
# Location
# Marital_Status
# Employment_Status
# Homeownership_Status
# Type_of_Housing
# Gender
# Primary_Mode_of_Transportation

# %% [markdown]
# ### Observations:
# - Mostly People educated from Bachelor's followed by High School, Masters and Doctorate
# - Mostly people has occupation in Healthcare and Technology
# - Mostly people belongs to Urban location
# - Mostly people are Married
# - Mostly people are Full Time employed and least people are self employed
# - Mostly people has their own house
# - Very least Family prefer Townhouse type of housing
# - Almost half families has male as primary household member and half has female
# - Mostly people prefer public transport or Car for transportation

# %% [markdown]
# ## 4.2. BiVariate Analysis

# %%
# ScatterPlot
for col in df:
    if col != "Income":
        sns.scatterplot(x=col, y='Income', data=df)
        plt.title(f'Scatter Plot:{col} vs. Annual Household Income')
        plt.show()

# %%
# Lineplot
for col in df:
    if col != "Income":
        sns.lineplot(x=col, y='Income', data=df)
        plt.title(f'Line Plot: {col} vs. Annual Household Income')
        plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Barplot
for col in df:
    if col != "Income":
        sns.barplot(x=col, y='Income', data=df)
        plt.title(f'Box Plot: {col} vs. Annual Household Income')
        plt.show()

# %% [markdown]
# ### Observations:
# - People living in Rural region has income high in general
# - People living in Townhouse has low income than people living in Apartment
# - People living in rented house has high Family Income
# - People living in rural locality has High Income

# %% [markdown]
# ## 4.3. MultiVariate Analysis

# %%
df1=df.select_dtypes(exclude=['object'])
plt.figure(figsize=(12, 7))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %% [markdown]
# # 5. Feature Encoding

# %%
from sklearn.model_selection import KFold
target = 'Income'
df_encoded = df.copy()

kf = KFold(n_splits=5, shuffle=True, random_state=1)

for col in cat_cols:
    col_encoded = f'{col}_encoded'
    df_encoded[col_encoded] = 0
    
    for train_index, val_index in kf.split(df):
        X_train, X_val = df.iloc[train_index], df.iloc[val_index]
        means = X_train.groupby(col)[target].mean()
        df_encoded.loc[val_index, col_encoded] = df.loc[val_index, col].map(means)
    df_encoded[col_encoded].fillna(df[target].mean(), inplace=True)
    df_encoded.drop(columns=[col], inplace=True)

df_encoded.head()
# Out:
# C:\Users\Sarthak Aggarwal\AppData\Local\Temp\ipykernel_25348\3132234140.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[805941.18071066 805941.18071066 858620.         ... 828724.91712707
#  858620.         858620.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_encoded.loc[val_index, col_encoded] = df.loc[val_index, col].map(means)
# C:\Users\Sarthak Aggarwal\AppData\Local\Temp\ipykernel_25348\3132234140.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# # 6. Train-test split

# %%
x=df_encoded.drop(["Income"],axis=1)
y=df_encoded["Income"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # 7. Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns, index=x_train.index)
x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns, index=x_test.index)

x_train_scaled.head()
# Out:
#            Age  Number_of_Dependents  Work_Experience  Household_Size  \
# 9254  0.500000                   0.8             0.54        1.000000
# 1561  0.519231                   0.4             0.38        1.000000
# 1670  0.961538                   1.0             0.52        0.666667
# 6087  0.673077                   0.0             0.50        0.000000
# 6669  0.500000                   0.4             0.32        0.833333
#
#       Education_Level_encoded  Occupation_encoded  Location_encoded  \
# 9254                 0.743339            0.554512          0.110182
# 1561                 0.734191            0.454272          0.505734
# 1670                 0.065924            0.871623          0.934945
# 6087                 0.700596            0.650210          0.129494
# 6669                 0.734191            0.650210          0.129494
#
#       Marital_Status_encoded  Employment_Status_encoded  \
# 9254                0.158188                   1.000000
# ...

# %% [markdown]
# # 8. Model Creation

# %% [markdown]
# ## 8.1 Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred_lr = lr.predict(x_test)

# %% [markdown]
# ## 8.2. Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
y_pred_gbr = gbr.predict(x_test)

# %% [markdown]
# ## 8.3 Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet
en = ElasticNet()
en.fit(x_train, y_train)
y_pred_en = en.predict(x_test)

# %% [markdown]
# ## 8.4. Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(x_train, y_train)
y_pred_lasso = lasso.predict(x_test)

# %% [markdown]
# ## 8.5 Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
y_pred_dt = dt.predict(x_test)

# %% [markdown]
# ## 8.6. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)

# %% [markdown]
# # 9. Model Selection

# %% [markdown]
# ### Comparing All Evaluation Metrics in Increasing Order

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Initialize an empty DataFrame for model comparison
model_comparison = pd.DataFrame(columns=['Model', 'MAE', 'MSE', 'RMSE', 'R²'])

# Define a function to add the model's metrics to the DataFrame
def add_model_metrics(model_name, y_test, y_pred):
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)
    
    return pd.DataFrame({
        'Model': [model_name],
        'MAE': [mae],
        'MSE': [mse],
        'RMSE': [rmse],
        'R²': [r2]
    })

# Gradient Boosting Regressor
model_comparison = pd.concat([model_comparison, add_model_metrics('Gradient Boosting Regressor', y_test, y_pred_gbr)], ignore_index=True)

# Linear Regression
model_comparison = pd.concat([model_comparison, add_model_metrics('Linear Regression', y_test, y_pred_lr)], ignore_index=True)

# Elastic Net Regression
model_comparison = pd.concat([model_comparison, add_model_metrics('Elastic Net Regression', y_test, y_pred_en)], ignore_index=True)

# Lasso Regression
model_comparison = pd.concat([model_comparison, add_model_metrics('Lasso Regression', y_test, y_pred_lasso)], ignore_index=True)

# Decision Tree Regressor
model_comparison = pd.concat([model_comparison, add_model_metrics('Decision Tree Regressor', y_test, y_pred_dt)], ignore_index=True)

# Random Forest Regressor
model_comparison = pd.concat([model_comparison, add_model_metrics('Random Forest Regressor', y_test, y_pred_rf)], ignore_index=True)

# Print the model comparison table
print(model_comparison)

# Plotting all evaluation metrics in increasing order
metrics = ['MAE', 'MSE', 'RMSE', 'R²']
plt.figure(figsize=(14, 10))

for i, metric in enumerate(metrics, 1):
    sorted_comparison = model_comparison.sort_values(by=metric, ascending=(metric != 'R²'))
    plt.subplot(2, 2, i)
    plt.bar(sorted_comparison['Model'], sorted_comparison[metric])
    plt.xlabel('Model')
    plt.ylabel(metric)
    plt.title(f'Model Comparison: {metric}')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sarthak Aggarwal\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Sarthak Aggarwal\AppData\Local\Temp\ipykernel_25348\1230198849.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   model_comparison = pd.concat([model_comparison, add_model_metrics('Gradient Boosting Regressor', y_test, y_pred_gbr)], ignore_index=True)
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Gradient Boosting is performing best on this dataset
